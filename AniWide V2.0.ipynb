# %%
# @title 1. **Setup** { display-mode: "form" }
# %%capture
# !pip install wget telethon nest_asyncio torf lbry-libtorrent ffmpeg
# !apt-get install -y aria2
# !gdown --id 1kNCut32-mZJ_joCORA2kydDb06ysTxDN
# !pip install --no-deps ./libtorrent-2.0.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
import libtorrent as lt

import os, sys
if not os.path.exists("torrent_downloader"):
    # !git clone https://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@github.com/Alein8130/torrent_downloader.git
else:
    print("Repo already cloned.")

sys.path.insert(0, "torrent_downloader")

from initialization import EnvironmentSetup
from userinputs import BatchProcessor
from hardsubber import HardSubber

setup_env = EnvironmentSetup()
setup_env.setup()

# %%
# @title 2. **Parameters & Batch Selection** { display-mode: "form" }
# @markdown ### 🎯 **ورودی‌ها**
torrent_link = ""  # @param {type:"string"}
video_name = ""  # @param {type:"string"}
episode_numbers = "01"  # @param {type:"string"}
telegram_id = "@pierresourne"  # @param {type:"string"}
# @markdown #### ⬇️در صورتی که تورنت دارای چند قسمت هست، روشن کنید ⬇️
is_batch = True  # @param {type:"boolean"}
# @markdown ##### ⬇️در صورتی که انیمه فیلم هست، روشن کنید ⬇️
is_movie = False  # @param {type:"boolean"}
# @markdown ---
# @markdown ### 📺 **کیفیت‌های خروجی**
encode_480p = True  # @param {type:"boolean"}
encode_720p = True  # @param {type:"boolean"}
encode_1080p = True  # @param {type:"boolean"}
# @markdown ---
# @markdown ### ⚙️ **تنظیمات پردازش**
# @markdown ##### ⚠️ **فقط در صورتی که می‌دونید چیکار می‌کنید تغییر بدید**
manual_audio_selection = False  # @param {type:"boolean"}
CRF = 25  # @param {type:"slider", min:0, step:1, max:51}
import libtorrent as lt
qualities = []
if encode_480p: qualities.append("848x480")
if encode_720p: qualities.append("1280x720")
if encode_1080p: qualities.append("1920x1080")

processor = BatchProcessor(
    torrent_link, video_name, episode_numbers, telegram_id,
    is_batch=is_batch, is_movie=is_movie,
    encode_480p=encode_480p, encode_720p=encode_720p, encode_1080p=encode_1080p,
    manual_audio_selection=manual_audio_selection,
    CRF=CRF
)

processor.prepare_batch()

# %%
# @title 3. **Process** and **Upload** { display-mode: "form" }
processor = HardSubber(processor.batch_info, manual_audio_selection=manual_audio_selection, telegram_bot_token="7652202887:AAEAWARE1g7mAK-ZY99t37apMX6rKwIDP6w")

await processor.process()
await processor.finalize_telegram()

print("All selected episodes processed!")
